# %%
import matplotlib.pyplot as plt
import numpy as np

xp = np.array([0,6])
yp = np.array([0, 250])

plt.plot(xp, yp)

plt.show()

# %%
import matplotlib.pyplot as plt
x=np.arange(10)
y = x+1
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(10)
y1 = 1-x
plt.plot(x,y,x,y1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

n = 3
t = np.arange(0, np.pi*2, 0.05)
y = np.sin(n* t)
plt.plot(t, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(n)
y = np.random.rand(n)
plt.bar(x, y)
plt.show()
